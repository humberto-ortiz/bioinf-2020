# %%
input_dna = "..."

# %%
input_dna
# Out:
# '...'

# %%
acount = 0
ccount = 0
gcount = 0
tcount = 0

# %%
for base in input_dna:
    if base == 'A':
        acount += 1
    if base == "C":
        ccount += 1
    if base == "G":
        gcount += 1
    if base == "T":
        tcount += 1
        
print(acount, ccount, gcount, tcount)
# Out:
# 251 240 250 230
